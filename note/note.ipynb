# %% [markdown]
# Device0:"GeForce RTX 2080 Ti"
# CUDA Driver Version:                            11.2
# CUDA Runtime Version:                           11.1
# Device Prop:                                    7.0
# Total amount of Global Memory:                  2964783104 bytes
# Number of SMs:                                  68
# Total amount of Constant Memory:                65536 bytes
# Total amount of Shared Memory per block:        49152 bytes
# Total number of registers available per block:  65536
# Warp size:                                      32
# Maximum number of threads per SM:               1024
# Maximum number of threads per block:            1024
# Maximum size of each dimension of a block:      1024 x 1024 x 64
# Maximum size of each dimension of a grid:       2147483647 x 65535 x 65535
# Maximum memory pitch:                           2147483647 bytes
# Texture alignmemt:                              32 bytes
# Clock rate:                                     1.54 GHz
# Memory Clock rate:                              7000 MHz
# Memory Bus Width:                               352-bit
#
# Device1:"GeForce RTX 2080 Ti"
# CUDA Driver Version:                            11.2
# CUDA Runtime Version:                           11.1
# Device Prop:                                    7.5
# Total amount of Global Memory:                  2964783104 bytes
# Number of SMs:                                  68
# Total amount of Constant Memory:                65536 bytes
# Total amount of Shared Memory per block:        49152 bytes
# Total number of registers available per block:  65536
# Warp size:                                      32
# Maximum number of threads per SM:               1024
# Maximum number of threads per block:            1024
# Maximum size of each dimension of a block:      1024 x 1024 x 64
# Maximum size of each dimension of a grid:       2147483647 x 65535 x 65535
# Maximum memory pitch:                           2147483647 bytes
# Texture alignmemt:                              32 bytes
# Clock rate:                                     1.54 GHz
# Memory Clock rate:                              7000 MHz
# Memory Bus Width:                               352-bit

# %% [markdown]
# 512:
# 1. cpu:5895.353 ms
#    naive gpu:23373.012 ms
# 1K:
# 1. cpu:50309.008 ms, 47540.234 ms
#    naive gpu:273316.188 ms,250138.547 ms

# %% [markdown]
# A:
# ---
# 8.500000 8.161530 4.891171
# 8.161530 8.500000 6.099652
# 4.891171 6.099652 8.500000
# ---
# ---
#  2-8.500000  1-8.500000  0-8.500000  2-8.161530  1-8.161530  0-8.161530  2-4.891171  1-4.891171  0-4.891171
#  2-8.161530  1-8.161530  0-8.161530  2-8.500000  1-8.500000  0-8.500000  2-6.099652  1-6.099652  0-6.099652
#  2-4.891171  1-4.891171  0-4.891171  2-6.099652  1-6.099652  0-6.099652  2-8.500000  1-8.500000  0-8.500000
# ---
#
# IA:
# ---
# 2.286685 -2.579945 0.535553
# -2.579945 3.153366 -0.778292
# 0.535553 -0.778292 0.367980
# ---
# ---
#  2.286685  -2.579945  0.535553
#  -2.579945  3.153366  -0.778292
#  0.535553  -0.778292  0.367980
# ---
#
# B:
# ---
#  7.485978  8.161530  7.180950
#  6.482017  7.485978  7.980745
#  2.645954  3.702587  7.485978
# ---
# ---
#  1-7.485978  0-7.485978  2-7.485978  1-6.482017  2-6.482017  0-6.482017  1-2.645954  2-2.645954  0-2.645954
#  1-8.161530  2-8.161530  0-8.161530  1-7.485978  2-7.485978  0-7.485978  1-3.702587  2-3.702587  0-3.702587
#  1-7.180950  2-7.180950  0-7.180950  1-7.980745  2-7.980745  0-7.980745  1-7.485978  2-7.485978  0-7.485978
#
# W:
# ---
# -0.092449 0.834003 0.299530
# -0.216972 0.671432 0.581940
# 0.507132 -0.977083 1.290044
# ---
# ---
#  1--0.092450  0--0.092450  2--0.092450  1--0.216972  2--0.216972  0--0.216972  1-0.507131  2-0.507131  0-0.507131
#  1-0.834003  2-0.834003  0-0.834003  1-0.671432  2-0.671432  0-0.671432  1--0.977083  2--0.977083  0--0.977083
#  1-0.299530  2-0.299530  0-0.299530  1-0.581940  2-0.581940  0-0.581940  1-1.290044  2-1.290044  0-1.290044

# %% [markdown]
# single:
#     CPU:
#         --1K: 47011.758 ms
#         --2K: 378948.812 ms
#         --3K: 1276311.375 ms
#         --4K: 3021605.500 ms
#         --5K: 5889156.500 ms
#
#     GPU-2080Ti:
#         AOAS:
#             --1K: 267.085 ms
#             --2K: 1269.743 ms
#             --3K: 3294.021 ms
#             --4K: 5078.799 ms
#             --5K: 12815.260 ms
#         SOA:
#             --1K: 268.674 ms
#             --2K: 1269.320 ms
#             --3K: 3282.386 ms
#             --4K: 5069.961 ms
#             --5K: 12789.682 ms
#
# double:
#     CPU:
#         --1K: 47982.105 ms
#         --2K: 379947.094 ms
#         --3K: 1292484.001 ms
#         --4K: 3023113.250 ms
#         --5K: 6013546.500 ms
#
#     GPU-2080Ti:
#         AOAS:
#             --1K: 321.336 ms
#             --2K: 1348.625 ms
#             --3K: 4217.041 ms
#             --4K: 9261.793 ms
#             --5K: 17761.113 ms
#             <!-- --10K: 145529.188 ms -->
#         SOA:
#             --1K: 351.032 ms
#             --2K: 1372.957 ms
#             --3K: 4259.629 ms
#             --4K: 9298.641 ms
#             --5K: 17823.559 ms

# %% [markdown]
# 1K:
# CUDA kernel launch with 1 blocks of 1024 threads OR block (64, 64) of thread (16, 16)
# Time to generate A: 124.756 ms
# Time to generate IA: 138.609 ms
# Time to generate B: 95.692 ms
# Time to generate Weight: 4.301 ms
# Time to generate Z: 0.759 ms
# Tiled_Kriging_AOAS
# Time to generate: 364.359 ms
#
# CUDA kernel launch with 1 blocks of 1024 threads OR block (64, 64) of thread (16, 16)
# Time to generate A: 68.924 ms
# Time to generate IA: 152.779 ms
# Time to generate B: 91.208 ms
# Time to generate Weight: 4.319 ms
# Time to generate Z: 0.778 ms
# Naive_Kriging_AOAS
# Time to generate: 318.265 ms
#
# 5K:
# CUDA kernel launch with 5 blocks of 1024 threads OR block (320, 320) of thread (16, 16)
# Time to generate A: 538.094 ms
# Time to generate IA: 16260.704 ms
# Time to generate B: 470.187 ms
# Time to generate Weight: 605.946 ms
# Time to generate Z: 4.443 ms
# Tiled_Kriging_AOAS
# Time to generate: 17879.828 ms
#
# CUDA kernel launch with 5 blocks of 1024 threads OR block (320, 320) of thread (16, 16)
# Time to generate A: 466.289 ms
# Time to generate IA: 16270.495 ms
# Time to generate B: 469.381 ms
# Time to generate Weight: 605.804 ms
# Time to generate Z: 4.357 ms
# Naive_Kriging_AOAS
# Time to generate: 17819.436 ms
#
# CUDA kernel launch with 5 blocks of 1024 threads OR block (320, 320) of thread (16, 16)
# Time to generate A: 480.389 ms
# Time to generate IA: 16268.051 ms
# Time to generate B: 469.649 ms
# Time to generate Weight: 603.174 ms
# Time to generate Z: 1.915 ms
# Naive_Kriging_SOA
# Time to generate: 17823.559 ms
#
# CUDA kernel launch with 320 blocks of 16 threads OR block (320, 320) of thread (16, 16)
# Time to generate A: 105.759 ms
# Time to generate IA: 16298.806 ms
# Time to generate B: 76.286 ms
# Time to generate Weight: 607.867 ms
# Time to generate Z: 1.810 ms
# Tiled_Kriging_AOAS
# Time to generate: 17091.045 ms
#
# CUDA kernel launch with 320 blocks of 16 threads OR block (320, 320) of thread (16, 16)
# Time to generate A: 76.460 ms
# Time to generate IA: 16344.207 ms
# Time to generate B: 76.792 ms
# Time to generate Weight: 611.224 ms
# Time to generate Z: 1.823 ms
# Naive_Kriging_AOAS
# Time to generate: 17113.580 ms
